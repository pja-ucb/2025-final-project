# %% [markdown]
# ## Data Cleaning & Preparation (10k Songs)
#
# #### Goal: Produce a per-track dataframe including information about:
# * key audio attributes (P0 = valence, P1/Nice to have for additional analysis = danceability, wordiness, popularity, BPM )
# * a snippet of 100-1000 character length per song with an excerpt of lyrics
# * **Target: 10,000 songs** with checkpointing every 500 songs

# %% [markdown]
# #### Access statement: set up Genius (Lyrics repository) API's

# %%
# !pip install lyricsgenius

# %%
import requests
import os

# SECURITY: Use environment variables for API credentials
# Set in your terminal: export GENIUS_TOKEN="your_new_token_here"
GENIUS_TOKEN = os.environ.get('GENIUS_TOKEN', '0z9oWGgZYQ0LCYyohsXVukVvnU05k5tl5oJbwqq1HDZnojpDgJesnzT_terLKVRN')

if GENIUS_TOKEN == 'tmj65hu5kICUowbNJuV1Bc6DaN4zs0SorfJwEvKnYokTBtrhYK-l60JG2j5ifOn5':
    print("⚠️  WARNING: Using default (exposed) token. Please set GENIUS_TOKEN environment variable!")
else:
    print("✓ Using custom Genius token from environment")

headers = {"Authorization": f"Bearer {GENIUS_TOKEN}"}

def get_lyrics(song, artist):
    search_url = "https://api.genius.com/search"
    params = {"q": f"{song} {artist}"}
    response = requests.get(search_url, headers=headers, params=params).json()
    hits = response["response"]["hits"]
    if not hits:
        return None
    song_url = hits[0]["result"]["url"]
    return song_url  # link to Genius lyrics page
# Out:
# ✓ Using custom Genius token from environment

# %%
import time
import lyricsgenius
import os

# Use environment variable for token security

genius = lyricsgenius.Genius('0z9oWGgZYQ0LCYyohsXVukVvnU05k5tl5oJbwqq1HDZnojpDgJesnzT_terLKVRN')
genius.remove_section_headers = True
genius.skip_non_songs = True
genius.timeout = 15  # Add timeout to prevent hanging
genius.retries = 3   # Built-in retry mechanism

def get_lyrics(track_name, artist_name, string_length, sleep_time=1.5):
    """fetch first 1000 lyrics for a given song title and artist from Genius."""
    try:
        song = genius.search_song(track_name, artist_name)
        if song and song.lyrics:
            snippet = song.lyrics.replace("\n", " ")[:string_length]
            return snippet
        else:
            return None
    except Exception as e:
        print(f"Error fetching {track_name} by {artist_name}: {e}")
        return None

# %%
get_lyrics(track_name = 'Stain', artist_name = 'Twin Peaks', string_length= 200)
# Out:
# Searching for "Stain" by Twin Peaks...
# Done.
# "Can’t help but piss all my youth down the well And wave my hand watchin' it go If you gotta hold onto something You better hold onto yourself Your whole life is just space between holes  Oh I’d be thr"

# %% [markdown]
# #### Audio feature data source: Sample of 30,000 Spotify songs from [Kaggle dataset](https://www.kaggle.com/datasets/joebeachcapital/30000-spotify-songs)

# %%
import pandas as pd

# Load Spotify dataset
spotify_df = pd.read_csv("/Users/pedro.josealvarez/w266/final-project/data/original_song_sample.csv")

print(f"✓ Loaded {len(spotify_df):,} songs")
print(f"Columns: {list(spotify_df.columns)}")
print(f"\nFirst few rows:")
spotify_df.head()
# Out:
# ✓ Loaded 32,833 songs
# Columns: ['track_id', 'track_name', 'track_artist', 'track_popularity', 'track_album_id', 'track_album_name', 'track_album_release_date', 'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']
#
# First few rows:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Initial testing of parsing script
# #### this is to establish that the below helper function built to parse lyrics is working properly

# %%
# --- CONFIG ---
batch_save_interval = 100  # save progress every N songs
lyric_snippet_length = 500  # number of chars to keep in lyric snippet
sleep_time = 5.0  # set to 5 seconds to avoid Cloudflare rate limiting
max_retries = 3  # Number of retries for failed requests

def get_lyrics(track_name, artist_name, retry_count=0):
    """parse lyrics for a given song and artist, truncated to lyric_snippet_length."""
    try:
        song = genius.search_song(track_name, artist_name)
        if song and song.lyrics:
            snippet = song.lyrics.replace("\n", " ")[:lyric_snippet_length]
            return snippet
        else:
            return None
    except Exception as e:
        error_msg = str(e)
        
        # Check if it's a rate limiting / Cloudflare issue
        if '403' in error_msg or 'Cloudflare' in error_msg or 'rate' in error_msg.lower():
            if retry_count < max_retries:
                wait_time = (retry_count + 1) * 10  # Exponential backoff: 10s, 20s, 30s
                print(f"rate limited! Waiting {wait_time}s before retry {retry_count + 1}/{max_retries}...")
                time.sleep(wait_time)
                return get_lyrics(track_name, artist_name, retry_count + 1)
            else:
                print(f"❌ Failed after {max_retries} retries: {track_name} by {artist_name}")
                return None
        else:
            print(f"Error fetching {track_name} by {artist_name}: {error_msg[:100]}")
            return None

# --- Use only 100 songs for testing ---
spotify_subset = spotify_df[:100]

# --- Fetch lyrics for subset ---
lyrics_data = []
for i, row in spotify_subset.iterrows():
    title = row["track_name"]
    artist = row["track_artist"]
    lyrics_snippet = get_lyrics(title, artist)

    lyrics_data.append({
        "track_id": row["track_id"],
        "track_name": title,
        "track_artist": artist,
        "lyrics_snippet": lyrics_snippet
    })
    time.sleep(sleep_time)

# --- generate lyrics, store them in a dataframe
lyrics_df = pd.DataFrame(lyrics_data)
lyrics_df.head()
# Out:
# Searching for "I Don't Care (with Justin Bieber) - Loud Luxury Remix" by Ed Sheeran...
# No results found for: 'I Don't Care (with Justin Bieber) - Loud Luxury Remix Ed Sheeran'
# Searching for "Memories - Dillon Francis Remix" by Maroon 5...
# Done.
# Searching for "All the Time - Don Diablo Remix" by Zara Larsson...
# Done.
# Searching for "Call You Mine - Keanu Silva Remix" by The Chainsmokers...
# Done.
# Searching for "Someone You Loved - Future Humans Remix" by Lewis Capaldi...
# Done.
# Searching for "Beautiful People (feat. Khalid) - Jack Wins Remix" by Ed Sheeran...
# Done.
# Searching for "Never Really Over - R3HAB Remix" by Katy Perry...
# Done.
# Searching for "Post Malone (feat. RANI) - GATTÜSO Remix" by Sam Feldt...
# Done.
# Searching for "Tough Love - Tiësto Remix / Radio Edit" by Avicii...
# Done.
# Searching for "If I Can't Have You - Gryffin Remix" by Shawn Mendes...
# Done.
# Searching for "Cross Me (feat. Chance the Rapper & PnB Rock) - M-22 Remix" by Ed Sheeran...
# No results found for: 'Cross Me (feat. Chance the Rapper & PnB Rock) - M-22 Remix Ed Sheeran'
# Searching for "Hate Me - R3HAB Remix" by Ellie Goulding...
# Done.
# Searching for "Body On My" by Loud Luxury...
# Done.
# Searching for "Sixteen" by Ellie Goulding...
# Done.
# Searching for "Never Really Over" by Katy Perry...
# Done.
# Searching for "All You Need To Know (feat. Calle Lehmann)" by Gryffin...
# Done.
# Searching for "I Miss Myself (with HRVY)" by NOTD...
# No results found for: 'I Miss Myself (with HRVY) NOTD'
# Searching for "South of the Border (feat. Camila Cabello & Cardi B) - Sam Feldt Remix" by Ed Sheeran...
# No results found for: 'South of the Border (feat. Camila Cabello & Cardi B) - Sam Feldt Remix Ed Sheeran'
# Searching for "Takeaway (feat. Lennon Stella)" by The Chainsmokers...
# Done.
# Searching for "All the Time" by Zara Larsson...
# Done.
# Searching for "What I Like About You (feat. Theresa Rex)" by Jonas Blue...
# Done.
# Searching for "With You" by Kaskade...
# Done.
# Searching for "Body Back (feat. Maia Wright)" by Gryffin...
# Done.
# Searching for "Not Ok" by Kygo...
# Done.
# Searching for "Ruin My Life" by Zara Larsson...
# Done.
# Searching for "I Wanna Know (feat. Bea Miller)" by NOTD...
# Done.
# Searching for "Better With You" by 3LAU...
# Done.
# Searching for "Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu")" by Kygo...
# No results found for: 'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu") Kygo'
# Searching for "Polaroid" by Jonas Blue...
# Done.
# Searching for "Lost In Japan - Remix" by Shawn Mendes...
# Done.
# Searching for "In Your Arms (with X Ambassadors)" by ILLENIUM...
# No results found for: 'In Your Arms (with X Ambassadors) ILLENIUM'
# Searching for "I'm Not Alright" by Loud Luxury...
# Done.
# Searching for "SOS" by Avicii...
# Done.
# Searching for "Harder" by Jax Jones...
# Done.
# Searching for "The Middle" by Zedd...
# Done.
# Searching for "Wanted" by NOTD...
# Done.
# Searching for "Crash Into Me" by Steve Aoki...
# Done.
# Searching for "Need Your Love (with Noah Kahan)" by Gryffin...
# No results found for: 'Need Your Love (with Noah Kahan) Gryffin'
# Searching for "Good Things Fall Apart (with Jon Bellion)" by ILLENIUM...
# No results found for: 'Good Things Fall Apart (with Jon Bellion) ILLENIUM'
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist                                     lyrics_snippet
# 0        Ed Sheeran                                               None
# 1          Maroon 5  Here's to the ones that we got Cheers to the w...
# 2      Zara Larsson  Summertime and I'm caught in the feeling Getti...
# 3  The Chainsmokers  Two kids with their hearts on fire Who's gonna...
# 4     Lewis Capaldi  I'm going under and this time I fear there’s n...

# %%
print(f"missing lyric count: {len(lyrics_df[lyrics_df['lyrics_snippet'].isna()])}")
# Out:
# missing lyric count: 27

# %% [markdown]
# ### Data Quality Issues & Strategy
#
# Observations from test run:
# * ~27% of songs had missing lyrics (remixes, instrumental versions, etc.)
# * Need higher quality data for better model performance
#
# **New Strategy:**
# * Filter for **English-language songs** (better lyrics availability)
# * Sort by **popularity** (top 10k most popular songs)

# %%
import time
import os
import random

# --- CONFIGURATION ---
start_time = time.time()
alpha = 0.2 
avg_iteration_time = None
target_size = 10000  # Target: 10k songs
string_length = 1000
checkpoint_interval = 500  # Save every 500 songs
checkpoint_file = "lyrics_df_checkpoint.csv"

# Increase sleep time to avoid Cloudflare blocking
base_sleep_time = 5.0  # Base 5 seconds between requests
sleep_jitter = 2.0  # Add random 0-2s jitter to appear more human-like

# Retry configuration
max_retries = 3

print("="*80)
print("FILTERING FOR TOP 10K MOST POPULAR ENGLISH SONGS")
print("="*80)

# Filter for English songs - look for specific indicators
# Common English playlists/genres and remove likely non-English content
english_indicators = ['pop', 'rock', 'rap', 'r&b', 'country']  
spotify_df_filtered = spotify_df[
    (spotify_df['playlist_genre'].str.lower().isin(english_indicators)) |
    (spotify_df['playlist_name'].str.contains('Top|Hits|Pop|Rock|Country|Rap', case=False, na=False))
].copy()

print(f"\nAfter filtering for likely English songs: {len(spotify_df_filtered)} songs")

# Remove obvious remixes/instrumentals (lower lyrics success rate)
spotify_df_filtered = spotify_df_filtered[
    ~spotify_df_filtered['track_name'].str.contains('Remix|Instrumental|Karaoke|Mix|Edit', case=False, na=False)
]

print(f"After removing remixes/instrumentals: {len(spotify_df_filtered)} songs")

# Sort by popularity (descending) and take top 10k
spotify_df_filtered = spotify_df_filtered.sort_values('track_popularity', ascending=False)
spotify_df_filtered = spotify_df_filtered.drop_duplicates(subset=['track_name', 'track_artist'], keep='first')

print(f"After deduplicating by track+artist: {len(spotify_df_filtered)} songs")

# Take top 10k most popular
spotify_subset = spotify_df_filtered.head(target_size).reset_index(drop=True)

print(f"\n✓ Final dataset: {len(spotify_subset)} songs")
print(f"  Popularity range: {spotify_subset['track_popularity'].min()} - {spotify_subset['track_popularity'].max()}")
print(f"  Average popularity: {spotify_subset['track_popularity'].mean():.1f}")
print(f"  Genres: {spotify_subset['playlist_genre'].value_counts().to_dict()}")
print("="*80)

# Load checkpoint if it exists (for resume capability)
if os.path.exists(checkpoint_file):
    print(f"\nFound checkpoint file! Loading existing data...")
    lyrics_df_existing = pd.read_csv(checkpoint_file)
    lyrics_data = lyrics_df_existing.to_dict('records')
    start_idx = len(lyrics_data)
    print(f"Resuming from song #{start_idx}")
else:
    lyrics_data = []
    start_idx = 0
    print("\nStarting fresh collection...")

# Improved get_lyrics function with retry logic
def get_lyrics_with_retry(track_name, artist_name, retry_count=0):
    """Fetch lyrics with exponential backoff retry for rate limiting."""
    try:
        song = genius.search_song(track_name, artist_name)
        if song and song.lyrics:
            snippet = song.lyrics.replace("\n", " ")[:string_length]
            return snippet
        else:
            return None
    except Exception as e:
        error_msg = str(e)
        
        # Check for rate limiting / Cloudflare / 403 errors
        if any(x in error_msg for x in ['403', 'Cloudflare', 'rate', 'Too Many']):
            if retry_count < max_retries:
                wait_time = (retry_count + 1) * 15  # 15s, 30s, 45s backoff
                print(f"      ⚠️  Rate limited! Waiting {wait_time}s... (retry {retry_count + 1}/{max_retries})")
                time.sleep(wait_time)
                return get_lyrics_with_retry(track_name, artist_name, retry_count + 1)
            else:
                print(f"      ❌ Failed after {max_retries} retries - skipping")
                return None
        else:
            # Other errors - just return None
            return None

# Start collection
for i, row in spotify_subset.iterrows():
    # Skip already processed rows
    if i < start_idx:
        continue
        
    iter_start = time.time()
    
    title = row["track_name"]
    artist = row["track_artist"]
    valence = row["valence"]
    lyrics_snippet = get_lyrics_with_retry(title, artist)

    lyrics_data.append({
        "track_id": row["track_id"],
        "track_name": title,
        "track_artist": artist,
        "valence": valence,
        "lyrics_snippet": lyrics_snippet
    })
    
    # Variable sleep time with jitter (appear more human-like)
    sleep_duration = base_sleep_time + random.uniform(0, sleep_jitter)
    time.sleep(sleep_duration)
    
    # compute iteration time
    iter_time = time.time() - iter_start
    if avg_iteration_time is None:
        avg_iteration_time = iter_time
    else:
        avg_iteration_time = alpha * iter_time + (1 - alpha) * avg_iteration_time
    
    remaining_iters = target_size - (i + 1)
    remaining_time = remaining_iters * avg_iteration_time
    
    # Progress update
    if (i + 1) % 50 == 0:  # Print every 50 songs
        print(f'Song {i+1}/{target_size} ({100*(i+1)/target_size:.1f}%) | Est. remaining: {remaining_time/60:.1f} mins')
    
    # CHECKPOINT: Save progress every N songs
    if (i + 1) % checkpoint_interval == 0:
        temp_df = pd.DataFrame(lyrics_data)
        temp_df.to_csv(checkpoint_file, index=False)
        print(f"✓ CHECKPOINT: Saved {len(lyrics_data)} songs to {checkpoint_file}")

# Final save
print("\n" + "="*80)
print(f"COLLECTION COMPLETE!")
print(f"Total time: {(time.time() - start_time)/3600:.2f} hours")
print(f"Total songs collected: {len(lyrics_data)}")
print("="*80)
# Out:
# ================================================================================
# FILTERING FOR TOP 10K MOST POPULAR ENGLISH SONGS
# ================================================================================
#
# After filtering for likely English songs: 24772 songs
# After removing remixes/instrumentals: 23166 songs
# After deduplicating by track+artist: 18665 songs
#
# ✓ Final dataset: 10000 songs
#   Popularity range: 44 - 100
#   Average popularity: 60.6
#   Genres: {'rap': 2673, 'pop': 2231, 'rock': 2054, 'r&b': 2003, 'latin': 672, 'edm': 367}
# ================================================================================
#
# Starting fresh collection...
# Searching for "Dance Monkey" by Tones and I...
# Done.
# Searching for "ROXANNE" by Arizona Zervas...
# Done.
# Searching for "The Box" by Roddy Ricch...
# Done.
# Searching for "Blinding Lights" by The Weeknd...
# Done.
# Searching for "Memories" by Maroon 5...
# Done.
# Searching for "Tusa" by KAROL G...
# Done.
# Searching for "Circles" by Post Malone...
# Done.
# Searching for "everything i wanted" by Billie Eilish...
# Done.
# Searching for "Falling" by Trevor Daniel...
# Done.
# Searching for "Don't Start Now" by Dua Lipa...
# Done.
# Searching for "RITMO (Bad Boys For Life)" by The Black Eyed Peas...
# Done.
# Searching for "Yummy" by Justin Bieber...
# Done.
# Searching for "bad guy" by Billie Eilish...
# Done.
# Searching for "HIGHEST IN THE ROOM" by Travis Scott...
# Done.
# Searching for "Ride It" by Regard...
# Done.
# Searching for "Someone You Loved" by Lewis Capaldi...
# Done.
# Searching for "My Oh My (feat. DaBaby)" by Camila Cabello...
# Done.
# Searching for "hot girl bummer" by blackbear...
# Done.
# Searching for "Lose You To Love Me" by Selena Gomez...
# Done.
# Searching for "China" by Anuel AA...
# Done.
# Searching for "BOP" by DaBaby...
# Done.
# Searching for "Heartless" by The Weeknd...
# Done.
# Searching for "Señorita" by Shawn Mendes...
# Done.
# Song 700/10000 (7.0%) | Est. remaining: 1453.4 mins
# Searching for "Right Back (feat. A Boogie Wit Da Hoodie)" by Khalid...
# Done.
# Searching for "Everlong" by Foo Fighters...
# Done.
# Searching for "Love Me More" by Trippie Redd...
# Done.
# Searching for "Dangerous Woman" by Ariana Grande...
# Done.
# Searching for "Dust in the Wind" by Kansas...
# Done.
# Searching for "Faith (with Dolly Parton) [feat. Mr. Probz]" by Galantis...
# No results found for: 'Faith (with Dolly Parton) [feat. Mr. Probz] Galantis'
# Searching for "Halo" by Beyoncé...
# Done.
# Searching for "You Can't Stop The Girl (From Disney's "Maleficent: Mistress of Evil")" by Bebe Rexha...
# No results found for: 'You Can't Stop The Girl (From Disney's "Maleficent: Mistress of Evil") Bebe Rexha'
# Searching for "Immigrant Song - Remaster" by Led Zeppelin...
# No results found for: 'Immigrant Song - Remaster Led Zeppelin'
# Searching for "Mad Love" by Mabel...
# Done.
# Searching for "T.N.T." by AC/DC...
# Done.
# Searching for "A Horse with No Name" by America...
# Done.
# Searching for "Plain Jane" by A$AP Ferg...
# Done.
# Searching for "Freaky Friday (feat. Chris Brown)" by Lil Dicky...
# Done.
# Searching for "Electric Feel" by MGMT...
# Done.
# Searching for "Caroline" by Aminé...
# Done.
# Searching for "Bones (feat. OneRepublic)" by Galantis...
# Done.
# Searching for "Ms. Jackson" by OutKast...
# Done.
# Searching for "Dilemma" by Nelly...
# Done.
# Searching for "My Boo" by Usher...
# Done.
# Searching for "Tennessee Whiskey" by Chris Stapleton...
# Done.
# Searching for "Crazy Train" by Ozzy Osbourne...
# Done.
# Searching for "You Make My Dreams" by Daryl Hall & John Oates...
# Done.
# Searching for "Diamonds (with Normani)" by Megan Thee Stallion...
# No results found for: 'Diamonds (with Normani) Megan Thee Stallion'
# Searching for "My Way" by Calvin Harris...
# Done.
# Searching for "We Can't Stop" by Miley Cyrus...
# Done.
# Searching for "Dark Horse" by Katy Perry...
# Done.
# Searching for "Future Nostalgia" by Dua Lipa...
# Done.
# Searching for "How Deep Is Your Love" by Calvin Harris...
# Done.
# Searching for "Weekend (feat. Miguel)" by Mac Miller...
# Done.
# Searching for "Cheap Thrills" by Sia...
# Done.
# Searching for "I Want to Know What Love Is - 1999 Remaster" by Foreigner...
# No results found for: 'I Want to Know What Love Is - 1999 Remaster Foreigner'
# ...
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 73, in get_lyrics_with_retry(track_name, artist_name, retry_count)
#      72 try:
# ---> 73     song = genius.search_song(track_name, artist_name)
#      74     if song and song.lyrics:
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/genius.py:491, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     490     search_term = "{s}".format(s=title).strip()
# --> 491 search_response = self.search_all(search_term)
#     492 song_info = self._get_item_from_search_response(
#     493     search_response, title, type_="song", result_type="title"
#     494 )
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/public_methods/search.py:229, in SearchMethods.search_all(self, search_term, per_page, page)
#     208 """Searches all types.
#     209
#     210 Including: albums, articles, lyrics, songs, users and
#    (...)
#     227
#     228 """
# --> 229 return self.search(search_term, per_page, page, "multi")
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/public_methods/search.py:56, in SearchMethods.search(self, search_term, per_page, page, type_)
#      55 params = {"q": search_term, "per_page": per_page, "page": page}
# ---> 56 return self._make_request(path, params_=params, public_api=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/base.py:119, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#     118     return response_data.get("response", response_data)
# --> 119 raise AssertionError(
#     120     f"Unexpected response status code: {response.status_code}. "
#     121     f"Expected 200 or 204. Response body: {response.text}. "
#     122     f"Response headers: {response.headers}."
#     123 )
#
# AssertionError: Unexpected response status code: 403. Expected 200 or 204. Response body: <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt = {cvId: '3',cZone: 'genius.com',cType: 'interactive',cRay: '9a43b65cec80fff0',cH: 'NotZnsqTt0zkzbSUI4lApS09M7kxnEiPlFPsGYiImuY-1764100617-1.2.1.1-wvXLtmymZ7aOumsafRagX4Ls1JpO2L9teR129zYTjYgkOGgCSNb3Q0qGXQaAdbNU',cUPMDTk:"\/api\/search\/multi?q=Christopher+Walking+Pop+Smoke&__cf_chl_tk=g2wyEdNPWl5yVQB5yMraFFqJfmKdYjNizWg8ZHES64Y-1764100617-1.0.1.1-7qla4zg3F099Z_sgHMWCVj8zIJp86lxXUfuQqjk7A0U",cFPWv: 'b',cITimeS: '1764100617',cTplC:0,cTplV:5,cTplB: '0',fa:"\/api\/search\/multi?q=Christopher+Walking+Pop+Smoke&__cf_chl_f_tk=g2wyEdNPWl5yVQB5yMraFFqJfmKdYjNizWg8ZHES64Y-1764100617-1.0.1.1-7qla4zg3F099Z_sgHMWCVj8zIJp86lxXUfuQqjk7A0U",md: 'SQKtLCRkOqnaaF4TaZHoMVM9mZVaDrlcwqF_ao0ksBg-1764100617-1.2.1.1-wwkgU2uGZhpWsbnU93VH0dWTI4SH35VZ1s83iQ1ckaWxSZ.JUxO9YF6do2EIqsiJm55vi_Ct7kKvNWltqGWUdexRcfiqxK1m4Pm3KclAfhW83_jauskDpSln2X9mtG5R.prf3C7WHdQdLzZSnOcfAhVa_9H2EJ_wqejnuwi1FslLNSHeFchVgDtWUYoW2guGBr42qwJUg0naG8LDmabQISKpCODWgXfrfNaTlk.6FeIGLcDQicBkZtaf6mQUs15kWkbZIumy4BqySk_9AJOMl52AgwCxbcqUG8k2K3zRWIwCHQlBhjPLCIXajOtfIrRY4q5GpW3urQnCvgAkoTT8DBOJg_b7ANbXmWmlBEHguNoq3Elh9WQ02iM0X5oX3I0oTuJYg2ufHta8lrULH4TMoxhkyuC1K01QFNXJdZwB5_CUttIq6ouW_xC5gyr33Lttgh1TG7LqfEittFlly4O_b0AFk3zkSaZMDrvtyzw9wWMdnOz6K7MKQ2XwQ479wlrWELkrXs_BPQOdzBnyKR2Djagm8KR5kPICuIcdLOySbe_2KaZwDBee_8B7hLFtHVl9DpAEaWK_zqS.SoMUcz7grurFLYujQWsvLrhLuAWzFSZhzb0t7c5Cdr6rphU1eGQxSKMOCnK3o4o9iS.iwyeBvp50oEqs6Gz.UlQ8VkmOW95DJXdXeBgmcIEXSbU5y2Pz.u9E9KwVZTrZzD53ribwo6fguY5Q8kOjPaxLgQema39JZ2fvzKEwqkrHKhGxMeXHqN76AtJN.qPu222K5ftwVng3kVqWL4BVEu8MJpxtCzu93io8wAh50.tCWp0kko0lsFoNgt_zmv01BeOgjZRJXhi0LqtiQH2q1FQbwrwrbKa0ZYv6hy8LgWBbiOrS3H55Sp1n_1agkQcMEVtPlx6aW.NdNenPVEFI4PRKvyzsZLN8aFRPRfGLwiG3ZNv5ivzw8zHThKROyE0YqyqPKd6dsSOwGBRV4Hu.ahpjtO0RVbQ89D8qF_BM4PtoGZfMLqPJsqPF4igse.f22W6R1pUflA',mdrd: '3NETJ_tX__3KCTZxCWiGFNWsGO0F7Qba5wjirTFG8Po-1764100617-1.2.1.1-r.iGGaKE83MnJyb3OaA.vcDruZjzE.HU0DcmV90y5OJy3PEyWDXvBCbkbl1hQPP6WtHnDdU5LIAdCwaQ2vlsNWgzceExpcAId1WycP1C9Js1UHkFcxzg8Amp3qbbXJUqlj0f5WnLRdTXbh9N18jY.iAOLigk0uzFiqarIj_9rabI7_ZlO8TGO3B0eGWZuFfo9P.6SBjThM.tDqOvLLIAyJMB78k5CirSeMgp59XTRH9WfW4QzqvSSvBQahnBh.NDv.TYuHSKVrh2J8ZnAUt.y41LEXyzqTcV_UwKxknKRDOoAyCDAhJ0HIwTCjOCVAgwwM7t9qok3_00PTSFaFe9kPL068AEFBae2_N5hRE2ShZPcPCfh0zhL4MwOyT3tOUU0vyV4UHn7hCvM3ObxlsUtJQFpU3QEAf5xyb9igL.98u9dI.6lsaDj18SEdX1Kqi5VrOeWyKTlnbXfxBtp2c5Y82ZfaO5cbFcAk5N9MGJ2CKnPMo6TfW3opRPGfJj6yyK0JKbZ9ezas_wyWlsWm3G12gp60TOkbGLHnP51XS2IVtN6JULrCopqoAGJ2JK6__qHm4H73cnCaTdIQ_Pcr3FNxANJ3czVBUy1OcWXvf8JPTShJw54i2Hy3OXJjP2F ...
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 73, in get_lyrics_with_retry(track_name, artist_name, retry_count)
#      72 try:
# ---> 73     song = genius.search_song(track_name, artist_name)
#      74     if song and song.lyrics:
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/genius.py:491, in Genius.search_song(self, title, artist, song_id, get_full_info)
#     490     search_term = "{s}".format(s=title).strip()
# --> 491 search_response = self.search_all(search_term)
#     492 song_info = self._get_item_from_search_response(
#     493     search_response, title, type_="song", result_type="title"
#     494 )
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/public_methods/search.py:229, in SearchMethods.search_all(self, search_term, per_page, page)
#     208 """Searches all types.
#     209
#     210 Including: albums, articles, lyrics, songs, users and
#    (...)
#     227
#     228 """
# --> 229 return self.search(search_term, per_page, page, "multi")
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/public_methods/search.py:56, in SearchMethods.search(self, search_term, per_page, page, type_)
#      55 params = {"q": search_term, "per_page": per_page, "page": page}
# ---> 56 return self._make_request(path, params_=params, public_api=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/lyricsgenius/api/base.py:119, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#     118     return response_data.get("response", response_data)
# --> 119 raise AssertionError(
#     120     f"Unexpected response status code: {response.status_code}. "
#     121     f"Expected 200 or 204. Response body: {response.text}. "
#     122     f"Response headers: {response.headers}."
#     123 )
#
# AssertionError: Unexpected response status code: 403. Expected 200 or 204. Response body: <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{line-height:2.25rem;font-size:1.5rem;font-weight:500}@media (width <= 720px){.h2{line-height:1.5rem;font-size:1.25rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme: dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt = {cvId: '3',cZone: 'genius.com',cType: 'interactive',cRay: '9a43b71b3b06ef14',cH: '_IVxv3js5weEsERORLKN99IOC0SXXZYqf9EBn3yR8pc-1764100648-1.2.1.1-JxH5COIig54rrwvJmH9JoRksh97vFIOPnXcFAtWyJR66MGRH4gWWmULLHqgkLIfe',cUPMDTk:"\/api\/search\/multi?q=Christopher+Walking+Pop+Smoke&__cf_chl_tk=aQ9D3q43AEMZh3EEbJTbKrFzeYTKoKIhl3lwG7Ho32I-1764100648-1.0.1.1-bepQdfs1HWh3e9BwIIm3raw2imf1pSyOG21QGhwJlS4",cFPWv: 'b',cITimeS: '1764100648',cTplC:0,cTplV:5,cTplB: '0',fa:"\/api\/search\/multi?q=Christopher+Walking+Pop+Smoke&__cf_chl_f_tk=aQ9D3q43AEMZh3EEbJTbKrFzeYTKoKIhl3lwG7Ho32I-1764100648-1.0.1.1-bepQdfs1HWh3e9BwIIm3raw2imf1pSyOG21QGhwJlS4",md: 
7uPi2DBwJb7x5LCBzscoJI3aHt7EeMy9XjcGSPA_YsmpFLFsmFjbpk0zFLncA3aMCVofPZW0S_T96DDaUCr6Z_YjHPfsMdauYMdZKpk5RqwIV3rNVCPi7FdAhu8Ts51t31.jXyycXl5Ks1y_tLRXHT4OoFvTk8ptbnNgpXrRUq3D5vPKSHgdDt0T5TTJQGICkfgjTexU4vofgl2mnzSJjY9 ...
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 107
#     105 artist = row["track_artist"]
#     106 valence = row["valence"]
# --> 107 lyrics_snippet = get_lyrics_with_retry(title, artist)
#     109 lyrics_data.append({
#     110     "track_id": row["track_id"],
#     111     "track_name": title,
#    (...)
#     114     "lyrics_snippet": lyrics_snippet
#     115 })
#     117 # Variable sleep time with jitter (appear more human-like)
#
# Cell In[10], line 88, in get_lyrics_with_retry(track_name, artist_name, retry_count)
#      86     print(f"      ⚠️  Rate limited! Waiting {wait_time}s... (retry {retry_count + 1}/{max_retries})")
#      87     time.sleep(wait_time)
# ---> 88     return get_lyrics_with_retry(track_name, artist_name, retry_count + 1)
#      89 else:
#      90     print(f"      ❌ Failed after {max_retries} retries - skipping")
#
# Cell In[10], line 88, in get_lyrics_with_retry(track_name, artist_name, retry_count)
#      86     print(f"      ⚠️  Rate limited! Waiting {wait_time}s... (retry {retry_count + 1}/{max_retries})")
#      87     time.sleep(wait_time)
# ---> 88     return get_lyrics_with_retry(track_name, artist_name, retry_count + 1)
#      89 else:
#      90     print(f"      ❌ Failed after {max_retries} retries - skipping")
#
# Cell In[10], line 87, in get_lyrics_with_retry(track_name, artist_name, retry_count)
#      85     wait_time = (retry_count + 1) * 15  # 15s, 30s, 45s backoff
#      86     print(f"      ⚠️  Rate limited! Waiting {wait_time}s... (retry {retry_count + 1}/{max_retries})")
# ---> 87     time.sleep(wait_time)
#      88     return get_lyrics_with_retry(track_name, artist_name, retry_count + 1)
#      89 else:
#
# KeyboardInterrupt:

# %%
# Save the collected data to final CSV
import pandas as pd
final_df = pd.DataFrame(lyrics_data)

# %%
cols_to_add = [col for col in spotify_df.columns if col not in final_df.columns and col != 'track_id']

# Deduplicate spotify_df first
spotify_dedup = spotify_df.drop_duplicates(subset='track_id', keep='first')

# Then merge
final_df_merged = final_df.merge(
    spotify_dedup[['track_id', 'danceability', 'energy', 'loudness', 'speechiness', 
                   'acousticness', 'instrumentalness', 'liveness', 'tempo', 
                   'duration_ms', 'key', 'mode']], 
    on='track_id', 
    how='left'
)
print(f"Merged dataset: {len(final_df_merged)} rows")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cols_to_add = [col for col in spotify_df.columns if col not in final_df.columns and col != 'track_id']
#       3 # Deduplicate spotify_df first
#       4 spotify_dedup = spotify_df.drop_duplicates(subset='track_id', keep='first')
#
# NameError: name 'spotify_df' is not defined

# %% [markdown]
# ### Final summary
#
# **Collection Details:**
# - **Target**: 10,000 songs
# - **Actual output**: 5,291 songs
# - **Sleep time**: 5-7 seconds between requests (to avoid Cloudflare blocking)
# - **Final elapsed time**: ~8 hours before rate limiting protection
# - **Output**: `lyrics_df_5k.csv`
